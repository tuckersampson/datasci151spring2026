# %% [markdown]
# These are where lecture notes are written, describing what's happening in code cells

# %% [markdown]
# There are different ways of changing fonts
#
#
#
# # BIG
#
# ### Smaller
#
# ###### Very small

# %%
print("hello, world")
# Out:
# hello, world

# %%
print("Hello World!")
# Out:
# Hello World!
